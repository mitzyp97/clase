# %% [markdown]
# <a href="https://colab.research.google.com/github/mitzyp97/clase/blob/main/Clase_8_04_06_25_apply_y_merge_profe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Apply
#
# El método .apply() sirve para aplicar una función a cada columna o fila de un DataFrame o a cada elemento de una serie.
# ```
# df["columna"].apply(funcion)
# ```

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
  "nombre": ["Ana", "Luis", "Sofía", "Maria", "Juan"],
  "edad": [21, 35, 17, 18, 15],
  "altura_cm": [160, 175, 158, 175, 160]
})

# %%
df
# Out:
#   nombre  edad  altura_cm
# 0    Ana    21        160
# 1   Luis    35        175
# 2  Sofía    17        158
# 3  Maria    18        175
# 4   Juan    15        160

# %%
# Convertir altura de cm a metros.

# Definir funcion.
def cm_to_m(medida: int) -> int:
  '''
  Convertir cm a m.
  '''
  return (medida/100)

# Aplicar funcion.
df["altura_m"] = df["altura_cm"].apply(cm_to_m)

# %%
df
# Out:
#   nombre  edad  altura_cm  altura_m
# 0    Ana    21        160      1.60
# 1   Luis    35        175      1.75
# 2  Sofía    17        158      1.58
# 3  Maria    18        175      1.75
# 4   Juan    15        160      1.60

# %%
# Podemos hacerlo tambien en una sola linea usando funciones anonimas.
df["altura_m_2"] = df["altura_cm"].apply(lambda x: x/100)

# %%
df
# Out:
#   nombre  edad  altura_cm  altura_m  altura_m_2
# 0    Ana    21        160      1.60        1.60
# 1   Luis    35        175      1.75        1.75
# 2  Sofía    17        158      1.58        1.58
# 3  Maria    18        175      1.75        1.75
# 4   Juan    15        160      1.60        1.60

# %%
# Clasificar edades.
def clasificar_edad(edad: int) -> str:
  '''
  Clasificar las edades.
  '''
  if edad < 18:
      return "Menor"
  elif edad < 30:
      return "Joven"
  else:
      return "Adulto"

df["grupo_edad"] = df["edad"].apply(clasificar_edad)

# %%
df
# Out:
#   nombre  edad  altura_cm  altura_m  altura_m_2 grupo_edad
# 0    Ana    21        160      1.60        1.60      Joven
# 1   Luis    35        175      1.75        1.75     Adulto
# 2  Sofía    17        158      1.58        1.58      Menor
# 3  Maria    18        175      1.75        1.75      Joven
# 4   Juan    15        160      1.60        1.60      Menor

# %%
# Tambien podemos usar mas de una columna en un solo apply.

def describir_fila(fila: pd.Series) -> str:
  '''
  Crear una descripcion en cada registro.
  '''
  return f"{fila['nombre']} tiene {fila['edad']} años y mide {fila['altura_cm']} cm"

df["descripcion"] = df.apply(describir_fila, axis=1)

# %%
df
# Out:
#   nombre  edad  altura_cm  altura_m  altura_m_2 grupo_edad  \
# 0    Ana    21        160      1.60        1.60      Joven
# 1   Luis    35        175      1.75        1.75     Adulto
# 2  Sofía    17        158      1.58        1.58      Menor
# 3  Maria    18        175      1.75        1.75      Joven
# 4   Juan    15        160      1.60        1.60      Menor
#
#                          descripcion
# 0    Ana tiene 21 años y mide 160 cm
# 1   Luis tiene 35 años y mide 175 cm
# 2  Sofía tiene 17 años y mide 158 cm
# 3  Maria tiene 18 años y mide 175 cm
# 4   Juan tiene 15 años y mide 160 cm

# %% [markdown]
# # Concat y Merge

# %% [markdown]
# ## Concat
#
# Une DataFrames por filas o columnas. Util cuando quiero unir 2 o mas DataFrames que comparten una estructura igual ya sea en columnas o filas.

# %% [markdown]
# - Caso 1: concatenamos por filas ya que se comparte la misma estructura de columnas.

# %%
# Definimos 2 DataFrame.
df1 = pd.DataFrame({"nombre": ["Ana", "Luis"], "edad": [25, 30]})
df2 = pd.DataFrame({"nombre": ["Sofía"], "edad": [22]})

# %%
df1
# Out:
#   nombre  edad
# 0    Ana    25
# 1   Luis    30

# %%
df2
# Out:
#   nombre  edad
# 0  Sofía    22

# %%
# Unimos 2 DataFrame y visualizamos.
# Notese ignoramos los index.
df_concatenado = pd.concat([df1, df2], ignore_index=True)
df_concatenado
# Out:
#   nombre  edad
# 0    Ana    25
# 1   Luis    30
# 2  Sofía    22

# %% [markdown]
# - Caso 2: concatenamos columnas ya que se comparte las mismas dimensiones de filas.

# %%
# Definimos 1 DataFrame.
df3 = pd.DataFrame({"altura": [160, 175, 158]})

# %%
df3
# Out:
#    altura
# 0     160
# 1     175
# 2     158

# %%
# Concatenamos.
# Notese que usamos axis=1 para indicar que estamos concatenando columnas.
df_concatenado_col = pd.concat([df_concatenado, df3], axis=1)

# %%
df_concatenado_col
# Out:
#   nombre  edad  altura
# 0    Ana    25     160
# 1   Luis    30     175
# 2  Sofía    22     158

# %% [markdown]
# ## Merge
#
# Une DataFrames según una clave o columna. Util cuando quiero unir DataFrames que no necesariamente comparten estructura pero si alguna columna.

# %%
# Definimos 2 DataFrame.
df_1 = pd.DataFrame({
  "nombre": ["Ana", "Luis", "Sofía"],
  "peso": [75, 80, 85],
})

df_2 = pd.DataFrame({
  "nombre": ["Ana", "Sofía", "Luis"],
  "altura": [180, 180, 175],
  "edad": [18, 25, 30],
})

# %%
df_1
# Out:
#   nombre  peso
# 0    Ana    75
# 1   Luis    80
# 2  Sofía    85

# %%
df_2
# Out:
#   nombre  altura  edad
# 0    Ana     180    18
# 1  Sofía     180    25
# 2   Luis     175    30

# %%
# Hacemos merge.
df_merged = pd.merge(df_1, df_2, on="nombre")

# %%
df_merged
# Out:
#   nombre  peso  altura  edad
# 0    Ana    75     180    18
# 1   Luis    80     175    30
# 2  Sofía    85     180    25

# %%
# Las dimensiones de los DataFrame no necesitan ser iguales, solo compartir una columna.
# Definimos 2 DataFrame.
df_1 = pd.DataFrame({
  "nombre": ["Ana", "Luis", "Sofía"],
  "peso": [75, 80, 85],
})

df_2 = pd.DataFrame({
  "nombre": ["Ana", "Juan", "Luis", "Sofía"],
  "edad": [25, 30, 22, 18],
  "altura": [180, 180, 175, 160],
})

# %%
df_1
# Out:
#   nombre  peso
# 0    Ana    75
# 1   Luis    80
# 2  Sofía    85

# %%
df_2
# Out:
#   nombre  edad  altura
# 0    Ana    25     180
# 1   Juan    30     180
# 2   Luis    22     175
# 3  Sofía    18     160

# %%
# Hacemos merge.
df_merged = df_1.merge(df_2, on="nombre", how="left")

# %%
df_merged
# Out:
#   nombre  peso  edad  altura
# 0    Ana    75    25     180
# 1   Luis    80    22     175
# 2  Sofía    85    18     160

# %%
# Tampoco es necesario que el nombre de la columna sea igual, pero si que su contenido tenga equivalencias.
# Definimos 2 DataFrame.
df_1 = pd.DataFrame({
  "nombre": ["Ana", "Luis", "Sofía"],
  "peso": [75, 80, 85],
})

df_2 = pd.DataFrame({
  "Nombres": ["Ana", "Juan", "Luis", "Sofía"],
  "edad": [25, 30, 22, 18],
  "altura": [180, 180, 175, 160],
})

# %%
df_1
# Out:
#   nombre  peso
# 0    Ana    75
# 1   Luis    80
# 2  Sofía    85

# %%
df_2
# Out:
#   Nombres  edad  altura
# 0     Ana    25     180
# 1    Juan    30     180
# 2    Luis    22     175
# 3   Sofía    18     160

# %%
# Hacemos merge.
df_merged = df_1.merge(df_2, left_on="nombre", right_on="Nombres", how="left")

# %%
df_merged
# Out:
#   nombre  peso Nombres  edad  altura
# 0    Ana    75     Ana    25     180
# 1   Luis    80    Luis    22     175
# 2  Sofía    85   Sofía    18     160

# %%
# Prueba.
df_merged = df_2.merge(df_1, left_on="Nombres", right_on="nombre", how="left")

# %%
df_merged
# Out:
#   Nombres  edad  altura nombre  peso
# 0     Ana    25     180    Ana  75.0
# 1    Juan    30     180    NaN   NaN
# 2    Luis    22     175   Luis  80.0
# 3   Sofía    18     160  Sofía  85.0
